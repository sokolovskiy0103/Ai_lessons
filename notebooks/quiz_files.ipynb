# %% [markdown]
# # Перевірка знань: Робота з файлами
#
# **20 питань.** Notebook складається з трьох частин:
#
# - **Частина 1 (1–8):** теоретичні питання — напишіть відповідь у клітинці нижче питання.
# - **Частина 2 (9–15):** знайдіть помилку — поясніть, у чому проблема, і напишіть виправлений код у порожній клітинці.
# - **Частина 3 (16–20):** що виведе код — спочатку напишіть свою відповідь, **не запускаючи** клітинку, потім перевірте себе.
#
# Під кожним питанням є згорнутий блок **«💡 Відповідь»** — відкривайте його лише після того, як дали власну відповідь!
#
# > Питання охоплюють: `open`, ключове слово `with`, режими файлів, читання/запис, відносні та абсолютні шляхи (на прикладі High Score у грі Snake).
#
# Успіхів! 🍀

# %% [markdown]
# ---
# ## Частина 1. Теорія

# %% [markdown]
# ### Питання 1
# Навіщо потрібне ключове слово **`with`** при роботі з файлами? Чим воно краще за звичайні `f = open(...)` та `f.close()`?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <code>with open(...) as f:</code> створює <b>контекстний менеджер</b>: він автоматично <b>закриває файл</b> при виході з блоку — навіть якщо станеться помилка чи <code>return</code>.<br><br>Зі звичайними <code>open()</code>/<code>close()</code> легко забути викликати <code>close()</code>, а якщо між ними виникне виняток — файл лишиться відкритим (дані можуть не записатися на диск, ресурс «висітиме»). <code>with</code> прибирає цей клопіт.<br><pre><code>with open("data.txt") as f:
#     text = f.read()
# # тут файл уже закритий</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 2
# Які є основні **режими** відкриття файлу (`mode`) у функції `open()`? Поясніть `"r"`, `"w"`, `"a"`.

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <ul><li><code>"r"</code> — <b>читання</b> (режим за замовчуванням). Файл має існувати, інакше <code>FileNotFoundError</code>.</li><li><code>"w"</code> — <b>запис</b>. Створює файл, а якщо він існує — <b>повністю стирає</b> його старий вміст!</li><li><code>"a"</code> — <b>дозапис</b> (append). Дописує в кінець файлу, не видаляючи наявне.</li></ul>Є ще <code>"r+"</code> (читання+запис) та суфікс <code>"b"</code> для бінарних даних (напр. <code>"rb"</code>).
#
# </details>

# %% [markdown]
# ### Питання 3
# Чим відрізняються методи **`read()`**, **`readline()`** та **`readlines()`**?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <ul><li><code>read()</code> — повертає <b>весь</b> вміст файлу одним рядком (<code>str</code>).</li><li><code>readline()</code> — повертає <b>один</b> наступний рядок (включно з <code>\n</code>).</li><li><code>readlines()</code> — повертає <b>список</b> усіх рядків (кожен із <code>\n</code> у кінці).</li></ul>Часто файл просто перебирають у циклі — це найекономніший спосіб:<br><pre><code>with open("f.txt") as f:
#     for line in f:
#         print(line.strip())</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 4
# Чим відрізняється **відносний** (relative) шлях від **абсолютного** (absolute)? Наведіть приклад кожного.

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <b>Абсолютний шлях</b> вказує повне розташування від кореня файлової системи й не залежить від того, звідки запущено програму:<br><pre><code>C:\\Users\\Ivan\\project\\data.txt   # Windows
# /home/ivan/project/data.txt        # macOS/Linux</code></pre><b>Відносний шлях</b> відраховується від <b>поточної робочої теки</b> (current working directory):<br><pre><code>data.txt           # файл поруч
# files/data.txt     # у підтеці files
# ../data.txt        # на рівень вище</code></pre><code>.</code> — поточна тека, <code>..</code> — батьківська.
#
# </details>

# %% [markdown]
# ### Питання 5
# Що станеться, якщо відкрити **наявний** файл у режимі `"w"` і записати в нього кілька рядків? Чим це небезпечно?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# Режим <code>"w"</code> при відкритті <b>одразу стирає</b> весь попередній вміст файлу (обрізає його до нуля), і записує туди нові дані. Старі дані <b>безповоротно втрачаються</b>.<br><br>Тому, якщо треба <b>додати</b> щось, не знищуючи наявне, використовують <code>"a"</code> (append). Класична помилка-«знищувач даних»: відкрити лог чи список у <code>"w"</code> замість <code>"a"</code>.
#
# </details>

# %% [markdown]
# ### Питання 6
# У грі Snake ми зберігаємо найкращий рахунок у файл. Чому при **читанні** числа з файлу його треба перетворювати через `int()`, а при **записі** — через `str()` (або f-рядок)?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# Файли зберігають <b>текст</b>: усе, що читаємо з файлу, повертається як <code>str</code>, а <code>write()</code> приймає <b>лише рядок</b>.<br><br>Тому з файлу ми отримуємо, напр., <code>"7"</code> (рядок) — щоб порівнювати з рахунком як з числом, робимо <code>int(data)</code>. А щоб записати число <code>10</code>, перетворюємо його на рядок: <code>f.write(str(10))</code>. Спроба <code>f.write(10)</code> дасть <code>TypeError: write() argument must be str, not int</code>.
#
# </details>

# %% [markdown]
# ### Питання 7
# Що поверне `f.read()`, якщо викликати його **двічі** поспіль для того самого відкритого файлу? Що таке «позиція курсора» у файлі?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# У файлі є <b>позиція курсора</b> — місце, з якого триватиме наступне читання. Після першого <code>read()</code> курсор опиняється в <b>кінці</b> файлу, тож другий <code>read()</code> поверне <b>порожній рядок</b> <code>""</code> — далі читати нема чого.<br><br>Щоб перечитати з початку, треба або відкрити файл знову, або перемотати курсор: <code>f.seek(0)</code>.
#
# </details>

# %% [markdown]
# ### Питання 8
# Що станеться при `open("missing.txt", "r")`, якщо такого файлу немає? А при `open("missing.txt", "w")`? Як акуратно обробити перший випадок?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <ul><li><code>"r"</code> для неіснуючого файлу → <code>FileNotFoundError</code>.</li><li><code>"w"</code> (та <code>"a"</code>) для неіснуючого файлу → файл буде <b>створено</b>, помилки немає.</li></ul>Щоб коректно обробити відсутність файлу (напр., перший запуск гри, коли рекорду ще немає), використовують <code>try/except</code>:<br><pre><code>try:
#     with open("score.txt") as f:
#         high = int(f.read())
# except FileNotFoundError:
#     high = 0</code></pre>
#
# </details>

# %% [markdown]
# ---
# ## Частина 2. Знайди помилку
#
# У кожному фрагменті коду є щонайменше одна помилка. Поясніть, у чому вона полягає, і напишіть виправлений код.

# %% [markdown]
# ### Питання 9
# Програма ніби працює, але файл інколи виявляється порожнім або пошкодженим, а ще колегам не подобається цей стиль. Як переписати правильно (і безпечніше)?

# %%
f = open("notes.txt", "w")
f.write("перший рядок\n")
f.write("другий рядок\n")
# ... купа коду ...
# close забули, або до нього не дійшло через помилку вище

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# Файл відкрито «вручну» і <b>не гарантовано закривається</b>: якщо забути <code>f.close()</code> або між <code>open</code> і <code>close</code> станеться виняток — дані можуть не «скинутися» на диск, а файл лишиться відкритим. Правильно — <code>with</code>, який закриє файл автоматично:<br><pre><code>with open("notes.txt", "w") as f:
#     f.write("перший рядок\n")
#     f.write("другий рядок\n")</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 10
# Ми хотіли **додати** новий запис у журнал, але після кожного запуску у файлі лишається лише останній рядок — попередні зникають. Чому?

# %%
with open("log.txt", "w") as f:
    f.write("Новий запис\n")

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# Режим <code>"w"</code> при кожному відкритті <b>стирає</b> весь вміст файлу перед записом, тому в журналі завжди лишається тільки останній рядок. Для дозапису потрібен режим <code>"a"</code> (append):<br><pre><code>with open("log.txt", "a") as f:
#     f.write("Новий запис\n")</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 11
# Порівняння рахунку з рекордом ніколи не спрацьовує правильно, а інколи код падає з `TypeError`. У чому проблема?

# %%
with open("highscore.txt") as f:
    high_score = f.read()

score = 12
if score > high_score:
    print("Новий рекорд!")

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <code>f.read()</code> повертає <b>рядок</b> (напр., <code>"7"</code>), а <code>score</code> — це <code>int</code>. Порівняння <code>int &gt; str</code> у Python 3 кидає <code>TypeError: '&gt;' not supported between instances of 'int' and 'str'</code>. Прочитане треба перетворити на число:<br><pre><code>with open("highscore.txt") as f:
#     high_score = int(f.read())
#
# if score &gt; high_score:
#     print("Новий рекорд!")</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 12
# Спроба зберегти новий рекорд у файл падає з помилкою. Що не так із записом?

# %%
high_score = 25
with open("highscore.txt", "w") as f:
    f.write(high_score)    # TypeError

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <code>write()</code> приймає <b>лише рядок</b>, а ми передаємо <code>int</code> → <code>TypeError: write() argument must be str, not int</code>. Число треба перетворити на рядок:<br><pre><code>with open("highscore.txt", "w") as f:
#     f.write(str(high_score))</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 13
# Файл точно лежить поруч зі скриптом, але програма падає з `FileNotFoundError`, коли її запускають з іншої теки. Чому так і як зробити надійніше?

# %%
with open("data.txt") as f:
    print(f.read())

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <code>"data.txt"</code> — <b>відносний шлях</b>: він шукається від <b>поточної робочої теки</b>, а не від теки скрипта. Якщо програму запустити з іншого місця, файл «зникає» → <code>FileNotFoundError</code>.<br><br>Надійніше — будувати шлях відносно самого файлу скрипта:<br><pre><code>from pathlib import Path
# path = Path(__file__).parent / "data.txt"
# with open(path) as f:
#     print(f.read())</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 14
# Другий цикл нічого не виводить, хоча файл точно не порожній. Чому другий прохід «порожній»?

# %%
with open("names.txt") as f:
    for line in f:
        print(line.strip())
    print("---")
    for line in f:            # нічого не виводить
        print(line.strip())

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# Після першого циклу <b>курсор файлу опинився в кінці</b>, тож другий цикл одразу впирається в кінець файлу й нічого не читає. Треба або перемотати курсор на початок (<code>f.seek(0)</code>), або зберегти рядки у список і працювати з ним:<br><pre><code>with open("names.txt") as f:
#     lines = f.readlines()
# for line in lines:
#     print(line.strip())
# for line in lines:        # тепер працює
#     print(line.strip())</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 15
# Хотіли відкрити файл, дописати рядок, а потім одразу прочитати весь вміст — але `read()` повертає порожньо (або падає). У чому проблема?

# %%
with open("notes.txt", "w") as f:
    f.write("привіт\n")
    text = f.read()      # читання у режимі запису
print(text)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[12], line 3
#       1 with open("notes.txt", "w") as f:
#       2     f.write("привіт\n")
# ----> 3     text = f.read()      # читання у режимі запису
#       4 print(text)
#
# UnsupportedOperation: not readable

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# Файл відкрито в режимі <code>"w"</code> — <b>лише для запису</b>, тому <code>read()</code> кидає <code>io.UnsupportedOperation: not readable</code>. До того ж після <code>write()</code> курсор стоїть у кінці. Щоб і писати, і читати, потрібен режим <code>"w+"</code> (або <code>"r+"</code>) та перемотування курсора:<br><pre><code>with open("notes.txt", "w+") as f:
#     f.write("привіт\n")
#     f.seek(0)
#     text = f.read()
# print(text)</code></pre>
#
# </details>

# %% [markdown]
# ---
# ## Частина 3. Що виведе код?
#
# Спочатку запишіть свою відповідь у клітинці *«Ваша відповідь»*, і лише потім запустіть код і перевірте себе. Якщо помилилися — поясніть собі, чому код працює інакше.

# %% [markdown]
# ### Питання 16

# %%
with open("demo.txt", "w") as f:
    f.write("рядок 1\n")
    f.write("рядок 2\n")

with open("demo.txt") as f:
    content = f.read()

print(content)
print("Кількість символів:", len(content))
# Out:
# рядок 1
# рядок 2
#
# Кількість символів: 16

# %% [markdown]
# ✍️ *Ваша відповідь (що буде виведено і чому):*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>рядок 1
# рядок 2
#
# Кількість символів: 16</code></pre>У файл записано два рядки, кожен із <code>\n</code>. <code>read()</code> повертає весь текст <code>"рядок 1\nрядок 2\n"</code>. При друку <code>\n</code> дають перенесення рядків (звідси «порожній» рядок перед наступним <code>print</code>). Символів: 7 + 1 + 7 + 1 = <b>16</b> (пробіли й <code>\n</code> рахуються).
#
# </details>

# %% [markdown]
# ### Питання 17

# %%
with open("nums.txt", "w") as f:
    f.write("10\n20\n30\n")

with open("nums.txt") as f:
    lines = f.readlines()

print(lines)
print(len(lines))
# Out:
# ['10\n', '20\n', '30\n']
# 3

# %% [markdown]
# ✍️ *Ваша відповідь (що буде виведено і чому):*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>['10\n', '20\n', '30\n']
# 3</code></pre><code>readlines()</code> повертає <b>список рядків</b>, причому символ переносу <code>\n</code> <b>залишається</b> в кінці кожного елемента. Рядків три.
#
# </details>

# %% [markdown]
# ### Питання 18

# %%
with open("score.txt", "w") as f:
    f.write("5")

with open("score.txt", "a") as f:
    f.write("7")

with open("score.txt") as f:
    print(f.read())
# Out:
# 57

# %% [markdown]
# ✍️ *Ваша відповідь (що буде виведено і чому):*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>57</code></pre>Спочатку <code>"w"</code> записує <code>"5"</code>. Потім <code>"a"</code> (<b>append</b>) <b>дописує</b> <code>"7"</code> в кінець, не стираючи наявне. Виходить рядок <code>"57"</code> (а не число 12 і не 7!).
#
# </details>

# %% [markdown]
# ### Питання 19

# %%
with open("hs.txt", "w") as f:
    f.write("8")

with open("hs.txt") as f:
    high = int(f.read())

score = 11
if score > high:
    high = score
    print(f"Новий рекорд: {high}")
else:
    print(f"Рекорд лишається: {high}")
# Out:
# Новий рекорд: 11

# %% [markdown]
# ✍️ *Ваша відповідь (що буде виведено і чому):*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>Новий рекорд: 11</code></pre>З файлу прочитано <code>"8"</code> і перетворено на <code>int</code> → <code>8</code>. Оскільки <code>11 &gt; 8</code>, оновлюємо рекорд і друкуємо «Новий рекорд: 11». Без <code>int()</code> порівняння впало б із <code>TypeError</code>.
#
# </details>

# %% [markdown]
# ### Питання 20
# Файл `data.txt` **не існує** на момент запуску. Що буде виведено?

# %%
try:
    with open("data.txt") as f:
        value = int(f.read())
except (FileNotFoundError, RuntimeError):
    value = 0
    with open("data.txt", "w") as f:
        f.write("0")

print("Значення:", value)
# Out:
# Значення: 0

# %% [markdown]
# ✍️ *Ваша відповідь (що буде виведено і чому):*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>Значення: 0</code></pre>Файлу немає, тож <code>open(..., "r")</code> кидає <code>FileNotFoundError</code> — керування переходить у <code>except</code>: ставимо <code>value = 0</code> і <b>створюємо</b> файл із вмістом <code>"0"</code> (режим <code>"w"</code> створює файл). Друкуємо «Значення: 0». Це типовий патерн «перший запуск»: рекорду ще немає — починаємо з нуля.
#
# </details>
