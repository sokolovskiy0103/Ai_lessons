# %% [markdown]
# # Перевірка знань: CSV та Pandas
#
# **20 питань.** Notebook складається з трьох частин:
#
# - **Частина 1 (1–8):** теоретичні питання — напишіть відповідь у клітинці нижче питання.
# - **Частина 2 (9–15):** знайдіть помилку — поясніть, у чому проблема, і напишіть виправлений код у порожній клітинці.
# - **Частина 3 (16–20):** що виведе код — спочатку напишіть свою відповідь, **не запускаючи** клітинку, потім перевірте себе.
#
# Під кожним питанням є згорнутий блок **«💡 Відповідь»** — відкривайте його лише після того, як дали власну відповідь!
#
# > Питання охоплюють: формат CSV, модуль `csv`, бібліотеку **pandas** — `read_csv`, `DataFrame` і `Series`, вибірку рядків/колонок, прості агрегації та запис `to_csv` (на прикладі гри «U.S. States»).
#
# > Перед роботою виконайте клітинку нижче.
#
# Успіхів! 🍀

# %%
import pandas as pd

print("pandas версія:", pd.__version__)

# %% [markdown]
# ---
# ## Частина 1. Теорія

# %% [markdown]
# ### Питання 1
# Що таке формат **CSV**? Як у ньому представлені рядки та колонки даних?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <b>CSV</b> (Comma-Separated Values) — простий <b>текстовий</b> формат для табличних даних. Кожен рядок файлу = один рядок таблиці; значення колонок у ньому розділені <b>комами</b> (рідше — крапкою з комою чи табуляцією). Зазвичай перший рядок — це <b>заголовки</b> колонок.<br><pre><code>name,score,city
# Ivan,90,Lviv
# Olena,85,Kyiv</code></pre>CSV легко читається людиною й відкривається будь-якою програмою для таблиць.
#
# </details>

# %% [markdown]
# ### Питання 2
# Чим зчитування CSV вбудованим модулем **`csv`** відрізняється від використання **`pandas`**? Коли зручніше pandas?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# Модуль <code>csv</code> (стандартна бібліотека) читає файл «вручну», рядок за рядком, повертаючи списки або словники — обробку (підрахунки, фільтри) пишемо самі.<br><br><b>pandas</b> завантажує CSV одним викликом <code>pd.read_csv()</code> у <code>DataFrame</code> — таблицю з готовими інструментами для вибірки, фільтрації, агрегації, статистики. Для <b>аналізу даних</b> pandas набагато зручніший; <code>csv</code> добрий для простих задач без зайвих залежностей.
#
# </details>

# %% [markdown]
# ### Питання 3
# Що таке **`DataFrame`** і що таке **`Series`** у pandas? Як вони пов'язані?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <b>DataFrame</b> — двовимірна таблиця (рядки × колонки), як аркуш Excel.<br><b>Series</b> — одновимірний масив значень з індексом, фактично <b>одна колонка</b> (або один рядок) таблиці.<br><br>Зв'язок: DataFrame складається з колонок, кожна з яких — це Series. Вибірка однієї колонки повертає Series:<br><pre><code>df["score"]        # це Series
# df[["name","score"]] # це знову DataFrame</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 4
# Як прочитати файл `data.csv` у pandas? Що поверне `df.head()` і навіщо він потрібен?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>import pandas as pd
# df = pd.read_csv("data.csv")</code></pre><code>read_csv</code> повертає <code>DataFrame</code>. <code>df.head()</code> показує <b>перші 5 рядків</b> (можна вказати число: <code>df.head(10)</code>) — це швидкий спосіб «зазирнути» у дані, перевірити заголовки й що файл прочитано правильно, не друкуючи всю (можливо величезну) таблицю.
#
# </details>

# %% [markdown]
# ### Питання 5
# Якими **двома** способами можна звернутися до колонки `"score"` у DataFrame `df`? Що повертає така вибірка?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# Два способи:<br><pre><code>df["score"]   # через квадратні дужки (надійний, працює завжди)
# df.score      # через крапку (лише якщо назва — коректний ідентифікатор)</code></pre>Обидва повертають <b>Series</b> — одну колонку. Запис через крапку не спрацює, якщо в назві колонки є пробіл/спецсимвол або вона збігається з назвою методу DataFrame (напр. <code>count</code>), тому <code>df["..."]</code> безпечніший.
#
# </details>

# %% [markdown]
# ### Питання 6
# Як вибрати з DataFrame **лише ті рядки**, де значення в колонці `"score"` більше за 80? Як називається цей прийом?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# Це <b>булеве (boolean) індексування</b> / фільтрація за умовою. Спершу будуємо Series з <code>True/False</code>, потім передаємо його в дужки:<br><pre><code>mask = df["score"] &gt; 80
# high = df[mask]
# # або коротко:
# high = df[df["score"] &gt; 80]</code></pre>У результаті лишаються лише рядки, де умова <code>True</code>. Кілька умов поєднують через <code>&amp;</code> (і) та <code>|</code> (або), кожну в дужках.
#
# </details>

# %% [markdown]
# ### Питання 7
# Які прості методи pandas допоможуть порахувати **середнє**, **максимум** і **скільки разів** трапляється кожне значення в колонці? Наведіть приклади.

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <ul><li><code>df["score"].mean()</code> — середнє;</li><li><code>df["score"].max()</code> / <code>.min()</code> / <code>.sum()</code> — макс/мін/сума;</li><li><code>df["city"].value_counts()</code> — скільки разів трапляється кожне значення (повертає Series, відсортований за спаданням);</li><li><code>df.describe()</code> — зведена статистика по числових колонках.</li></ul>
#
# </details>

# %% [markdown]
# ### Питання 8
# Як **записати** DataFrame назад у CSV-файл? Що робить параметр `index=False` і навіщо він зазвичай потрібен?

# %% [markdown]
# ✍️ *Ваша відповідь:*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>df.to_csv("result.csv", index=False)</code></pre><code>to_csv</code> зберігає таблицю у CSV. За замовчуванням pandas <b>додає окрему колонку з індексом</b> (0, 1, 2, …) на початку файлу. <code>index=False</code> вимикає це, щоб у файлі були лише «справжні» дані — інакше при кожному перечитуванні з'являлася б зайва колонка <code>Unnamed: 0</code>.
#
# </details>

# %% [markdown]
# ---
# ## Частина 2. Знайди помилку
#
# У кожному фрагменті коду є щонайменше одна помилка. Поясніть, у чому вона полягає, і напишіть виправлений код.

# %% [markdown]
# ### Питання 9
# Код мав вивести місто кожного рядка, але падає з помилкою (`AttributeError`/`KeyError`). Що не так із читанням через модуль `csv`?

# %%
import csv

with open("data.csv") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row.city)   # ?

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <code>csv.reader</code> віддає кожен рядок як <b>список</b> (<code>list</code>), у якого немає атрибута <code>.city</code> — звідси <code>AttributeError</code>. До значень звертаються <b>за індексом</b> (<code>row[2]</code>), або, щоб мати доступ за назвою колонки, використовують <code>csv.DictReader</code>:<br><pre><code>with open("data.csv") as f:
#     reader = csv.DictReader(f)
#     for row in reader:
#         print(row["city"])</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 10
# Хотіли отримати колонку, але pandas кидає `KeyError`. Чому?

# %%
import pandas as pd

df = pd.read_csv("data.csv")
print(df("score"))   # ?

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# Колонку вибирають <b>квадратними</b> дужками <code>df["score"]</code>, а не круглими. <code>df("score")</code> — це спроба <b>викликати</b> DataFrame як функцію, що дає <code>TypeError: 'DataFrame' object is not callable</code> (а з квадратними неправильна назва — <code>KeyError</code>).<br><pre><code>print(df["score"])</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 11
# Звертання до колонки `"max"` через крапку повертає не дані, а щось дивне (`<bound method ...>`). У чому пастка і як зробити правильно?

# %%
import pandas as pd

df = pd.read_csv("data.csv")   # є колонка "max"
print(df.max)

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <code>df.max</code> через крапку звертається не до колонки, а до <b>методу</b> <code>DataFrame.max</code> — тому друкується об'єкт-метод, а не дані. Коли назва колонки збігається з назвою методу (<code>max</code>, <code>count</code>, <code>mean</code>…) або містить пробіл, треба <b>квадратні дужки</b>:<br><pre><code>print(df["max"])</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 12
# Після кожного збереження й повторного читання у таблиці з'являється зайва колонка `Unnamed: 0`, яка щораз множиться. Через що це і як прибрати?

# %%
import pandas as pd

df = pd.read_csv("states.csv")
# ... якісь зміни ...
df.to_csv("states.csv")   # ?

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <code>to_csv</code> за замовчуванням записує ще й <b>колонку індексу</b>. При наступному <code>read_csv</code> вона стає звичайною колонкою <code>Unnamed: 0</code>, і з кожним циклом таких колонок більшає. Треба вимкнути запис індексу:<br><pre><code>df.to_csv("states.csv", index=False)</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 13
# Фільтр рядків падає з помилкою про «truth value of a Series is ambiguous». Що не так?

# %%
import pandas as pd

df = pd.read_csv("data.csv")
high = df[df["score"] > 50 and df["score"] < 90]
print(high)

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# У pandas умови над Series не можна поєднувати ключовими словами <code>and</code>/<code>or</code> — звідси «truth value of a Series is ambiguous». Використовують поелементні оператори <code>&amp;</code> / <code>|</code>, причому <b>кожну умову беруть у дужки</b> (через пріоритет операцій):<br><pre><code>high = df[(df["score"] &gt; 50) &amp; (df["score"] &lt; 90)]</code></pre>
#
# </details>

# %% [markdown]
# ### Питання 14
# Хотіли витягти конкретне значення з рядка, де штат — `"California"`, але код повертає не один рядок-Series, а ціле число / падає. У чому помилка вибірки?

# %%
import pandas as pd

data = pd.read_csv("50_states.csv")
row = data[data.state == "California"]
x = row.x        # хотіли координату x
print(int(x))    # ValueError

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <code>data[data.state == "California"]</code> повертає <b>DataFrame</b> (нехай і з одного рядка), тож <code>row.x</code> — це <b>Series</b>, а не одне число; <code>int(Series)</code> падає. Щоб дістати <b>скаляр</b>, беруть конкретний елемент, напр. через <code>.values[0]</code> (або <code>.item()</code>, або <code>.iloc[0]</code>):<br><pre><code>row = data[data.state == "California"]
# x = row.x.values[0]   # одне число
# print(int(x))</code></pre>Саме так у грі «U.S. States» дістають координати, щоб поставити підпис штату на мапу.
#
# </details>

# %% [markdown]
# ### Питання 15
# Очікували одне число — середній бал, — а отримали цілу таблицю середніх. Чому `df.mean()` дав не те, і як порахувати середнє саме по колонці `"score"`?

# %%
import pandas as pd

df = pd.read_csv("data.csv")   # колонки: score, age, height
average = df.mean(numeric_only=True)
print("Середній бал:", average)

# %% [markdown]
# ✍️ *У чому помилка?*

# %%
# Виправлений код:

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <code>df.mean()</code> рахує середнє <b>по кожній числовій колонці</b> й повертає <b>Series</b> (score, age, height — три середніх), а не одне число. Щоб отримати середнє саме балів, спершу виберіть колонку:<br><pre><code>average = df["score"].mean()
# print("Середній бал:", average)</code></pre>
#
# </details>

# %% [markdown]
# ---
# ## Частина 3. Що виведе код?
#
# Спочатку запишіть свою відповідь у клітинці *«Ваша відповідь»*, і лише потім запустіть код і перевірте себе. Якщо помилилися — поясніть собі, чому код працює інакше.

# %% [markdown]
# > ⚠️ У питаннях 16–20 DataFrame створюється прямо в коді (без зовнішнього файлу), тому клітинки можна запускати для самоперевірки.

# %% [markdown]
# ### Питання 16

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Ivan", "Olena", "Petro"],
    "score": [90, 85, 70],
})

col = df["score"]
print(type(col).__name__)
print(col.sum())

# %% [markdown]
# ✍️ *Ваша відповідь (що буде виведено і чому):*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>Series
# 245</code></pre>Вибірка однієї колонки <code>df["score"]</code> повертає <b>Series</b> (тому <code>type(...).__name__</code> = <code>Series</code>). <code>sum()</code> по ній: 90 + 85 + 70 = <b>245</b>.
#
# </details>

# %% [markdown]
# ### Питання 17

# %%
import pandas as pd

df = pd.DataFrame({
    "city": ["Lviv", "Kyiv", "Lviv", "Lviv", "Kyiv"],
})

print(df["city"].value_counts())

# %% [markdown]
# ✍️ *Ваша відповідь (що буде виведено і чому):*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>city
# Lviv    3
# Kyiv    2
# Name: count, dtype: int64</code></pre><code>value_counts()</code> рахує, скільки разів трапляється кожне значення, і повертає Series, <b>відсортований за спаданням</b>: «Lviv» — 3 рази, «Kyiv» — 2.
#
# </details>

# %% [markdown]
# ### Питання 18

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Ivan", "Olena", "Petro", "Maria"],
    "score": [90, 60, 75, 50],
})

result = df[df["score"] >= 75]
print(result["name"].tolist())

# %% [markdown]
# ✍️ *Ваша відповідь (що буде виведено і чому):*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>['Ivan', 'Petro']</code></pre>Булевий фільтр <code>df["score"] &gt;= 75</code> лишає рядки Ivan (90) і Petro (75); Olena (60) і Maria (50) відсіюються. <code>result["name"].tolist()</code> перетворює колонку імен у звичайний список Python.
#
# </details>

# %% [markdown]
# ### Питання 19

# %%
import pandas as pd

df = pd.DataFrame({
    "product": ["A", "B", "C"],
    "price": [10, 20, 30],
})

print(df["price"].mean())
print(df["price"].max())

# %% [markdown]
# ✍️ *Ваша відповідь (що буде виведено і чому):*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>20.0
# 30</code></pre>Середнє по колонці <code>price</code>: (10 + 20 + 30) / 3 = <b>20.0</b> (mean повертає <code>float</code>). Максимум — <b>30</b>.
#
# </details>

# %% [markdown]
# ### Питання 20
# Це спрощена логіка з гри «U.S. States»: за вгаданою назвою штату дістаємо його координати.

# %%
import pandas as pd

data = pd.DataFrame({
    "state": ["California", "Texas", "Ohio"],
    "x": [-300, 50, 200],
    "y": [10, -40, 90],
})

guess = "Texas"
if guess in data["state"].values:
    row = data[data["state"] == guess]
    print(row["x"].values[0], row["y"].values[0])
else:
    print("Немає такого штату")

# %% [markdown]
# ✍️ *Ваша відповідь (що буде виведено і чому):*

# %% [markdown]
# <details>
# <summary>💡 Відповідь</summary>
#
# <pre><code>50 -40</code></pre><code>guess in data["state"].values</code> перевіряє, чи є «Texas» серед назв — так. Фільтр <code>data[data["state"] == "Texas"]</code> дає рядок Техасу; <code>row["x"].values[0]</code> і <code>row["y"].values[0]</code> дістають <b>скалярні</b> координати <code>50</code> і <code>-40</code>. Саме за такими координатами гра ставить підпис штату на мапу.
#
# </details>
